# %%
import networkx as nx

# %%
g_nlg = nx.read_gexf('out/elbulli_nlg.gexf')

# %%
g_dat = nx.read_gexf('out/elbulli_dat.gexf')

# %%
prep_prod_rels = ['bañado', 'alcohol', 'chocolate', 'lacteo', 'nuevaPasta', 'producto', 'relleno']
prep_ingr_rels = ['composicion']
prep_flav_rels = ['sabor']
prep_tech_rels = ['tecnica']

def get_prep_products(g, prep):
    return {k for k in g[prep] if g[prep][k]['edgetype'] in prep_prod_rels}

def get_prep_ingredients(g, prep):
    return {k for k in g[prep] if g[prep][k]['edgetype'] in prep_ingr_rels}

def get_prep_flavors(g, prep):
    return {k for k in g[prep] if g[prep][k]['edgetype'] in prep_flav_rels}

def get_prep_components(g, prep):
    prods = get_prep_products(g, prep)
    prods = set(map(lambda x: x.replace('Producto:', ''), prods))
    ingrs = get_prep_ingredients(g, prep)
    flavs = get_prep_flavors(g, prep)
    flavs = set(map(lambda x: x.replace('sabor:', ''), flavs))
    return prods.union(ingrs).union(flavs)

def get_prep_techniques(g, prep):
    return {k for k in g[prep] if g[prep][k]['edgetype'] in prep_tech_rels}

def get_recip_preparations(g, recip):
    return [k for k in g[recip] if g[recip][k]['edgetype'] == 'elaboracion']

def get_recip_products(g, recip):
    preps = get_recip_preparations(g, recip)
    return {k for prep in preps for k in get_prep_products(g, prep)}

def get_recip_ingredients(g, recip):
    preps = get_recip_preparations(g, recip)
    return {k for prep in preps for k in get_prep_ingredients(g, prep)}

def get_recip_flavors(g, recip):
    preps = get_recip_preparations(g, recip)
    return {k for prep in preps for k in get_prep_flavors(g, prep)}

def get_recip_components(g, recip):
    preps = get_recip_preparations(g, recip)
    return {k for prep in preps for k in get_prep_components(g, prep)}

def get_recip_techniques(g, recip):
    preps = get_recip_preparations(g, recip)
    return {k for prep in preps for k in get_prep_techniques(g, prep)}

def get_nodes_by_type(g, typ):
    return [n for n, data in g.nodes_iter(data=True) if data['nodetype'] == typ]

def get_recipes(g):
    ids_str = get_nodes_by_type(g, 'Receta')
    ids_int = map(int, ids_str)
    ids_ord = sorted(ids_int)
    ids_str = list(map(str, ids_ord))
    return ids_str

# %%
for n in get_recipes(g_dat):
    print('Recipe #{}'.format(n))
    print('============')
    print()
    preps_dat = get_recip_preparations(g_dat, n)
    print('Preparations dat')
    print('----------------')
    for prep in sorted(preps_dat):
        print('Preparation {}: {}'.format(prep, get_prep_components(g_dat, prep)))
    print()
    preps_nlg = get_recip_preparations(g_nlg, n)
    print('Preparations nlg')
    print('----------------')
    for prep in sorted(preps_nlg):
        print('Preparation {}: {}'.format(prep, get_prep_components(g_nlg, prep)))
    print()
    print('*' * 80)
    print()
# Out:
# Recipe #1
# ============
#
# Preparations dat
# ----------------
# Preparation 1-1: {'melón'}
# Preparation 1-2: {'oporto', 'agua', 'hojas de gelatina'}
# Preparation 1-3: {'gelatina de oporto', 'melón'}
# Preparation 1-4: {'pimienta blanca', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-523: {'oporto', 'agua', 'hojas de gelatina'}
# Preparation Elaboracion19871997-542: {'gelatina de oporto', 'melón'}
#
# ********************************************************************************
#
# Recipe #2
# ============
#
# Preparations dat
# ----------------
# Preparation 2-1: {'nata líquida', 'sal', 'agua', 'hojas de gelatina', 'jugo de trufa negra'}
# Preparation 2-2: {'trufas negras'}
# Preparation 2-3: {'trufa negra', 'aceite de girasol'}
# Preparation 2-4: {'aceite de trufa negra', 'jugo de trufa negra', 'avellanas'}
# Preparation 2-5: {'perifollo'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-299: {'aceite de trufa negra', 'avellana', 'jugo de trufa negra'}
# Preparation Elaboracion19871997-551: {'trufa negra', 'nata', 'hojas de gelatina', 'jugo de trufa negra'}
#
# ********************************************************************************
#
# Recipe #3
# ============
#
# Preparations dat
# ----------------
# Preparation 3-1: {'cigalas'}
# Preparation 3-2: {'levadura', 'sal', 'harina de trigo', 'agua', 'azúcar'}
# Preparation 3-3: {'zumo de limón', 'limón', 'cebollino fresco'}
# Preparation 3-4: {'huevos enteros', 'harina de trigo', 'sal', 'aceite de oliva'}
# Preparation 3-5: {'aceite de oliva', 'sal', 'caviar osietra', 'cebollino fresco', 'aceite de girasol'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-256: {'cebollino', 'limón', 'zumo de limón'}
# Preparation Elaboracion19871997-465: {'pasta fresca', 'limón', 'cigala', 'caviar', 'cebollino'}
# Preparation Elaboracion19871997-534: {'harina', 'sal', 'huevo', 'aceite de oliva'}
# Preparation Elaboracion19871997-567: set()
#
# ********************************************************************************
#
# Recipe #4
# ============
#
# Preparations dat
# ----------------
# Preparation 4-1: {'blanqueta de ternera', 'puerro', 'cebolla', 'tomate maduro', 'agua', 'rodilla de ternera', 'aceite de oliva', 'zanahoria', 'vino tinto', 'azúcar'}
# Preparation 4-10: {'pimienta negra', 'sal', 'cebollino fresco', 'aceite de oliva'}
# Preparation 4-2: {'cigalas'}
# Preparation 4-3: {'mantequilla'}
# Preparation 4-4: {'mantequilla', 'patata', 'sal'}
# Preparation 4-5: {'trufa negra'}
# Preparation 4-6: {'láminas de trufa negra', 'cigala', 'láminas de patata'}
# Preparation 4-7: {'calamares'}
# Preparation 4-8: {'endibia'}
# Preparation 4-9: {'trufa negra', 'pimienta negra', 'oporto', 'fondo de carne', 'jugo de trufa negra', 'chalota', 'mantequilla', 'sal'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-224: {'trufa negra', 'oporto', 'mantequilla', 'chalota', 'fondo de carne'}
# Preparation Elaboracion19871997-586: {'patata'}
# Preparation Elaboracion19871997-597: {'trufa negra', 'cigala', 'láminas de patata'}
#
# ********************************************************************************
#
# Recipe #5
# ============
#
# Preparations dat
# ----------------
# Preparation 5-1: {'levadura', 'sal', 'harina de trigo', 'agua', 'azúcar'}
# Preparation 5-2: {'trufa negra'}
# Preparation 5-3: {'aceite de oliva', 'ajo', 'sal', 'pimienta negra', 'azúcar', 'tomates'}
# Preparation 5-4: {'agua de mar', 'mantequilla', 'orégano fresco', 'tomate', 'aceite de oliva'}
# Preparation 5-5: set()
# Preparation 5-6: {'nata líquida', 'piñones', 'flores de calabacín', 'mozzarella'}
# Preparation 5-7: {'perifollo', 'sal', 'cebollino fresco', 'aceite de girasol'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-184: {'agua de mar', 'mantequilla', 'orégano', 'tomate', 'aceite de oliva'}
#
# ********************************************************************************
#
# Recipe #6
# ============
#
# Preparations dat
# ----------------
# Preparation 6-1: {'blanqueta de ternera', 'puerro', 'cebolla', 'tomate maduro', 'agua', 'rodilla de ternera', 'aceite de oliva', 'zanahoria', 'vino tinto', 'azúcar'}
# Preparation 6-2: {'fondo de carne', 'salsa de soja', 'mantequilla'}
# Preparation 6-3: {'codorniz'}
# Preparation 6-4: {'patatas'}
# Preparation 6-5: {'espárragos verdes'}
# Preparation 6-6: {'ajos tiernos'}
# Preparation 6-7: {'hierba luisa fresca'}
# Preparation 6-8: {'jengibre fresco'}
# Preparation 6-9: {'aceite de oliva', 'pimienta negra', 'sal', 'orégano fresco', 'harina de trigo', 'salsa de soja'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-300: {'fondo de carne', 'salsa de soja', 'mantequilla'}
# Preparation Elaboracion19871997-569: set()
#
# ********************************************************************************
#
# Recipe #7
# ============
#
# Preparations dat
# ----------------
# Preparation 7-1: {'patatas', 'sal', 'aceite de oliva'}
# Preparation 7-2: {'trufas negras'}
# Preparation 7-3: {'salmón'}
# Preparation 7-4: {'sal', 'láminas de trufa negra', 'salmón', 'láminas de patata'}
# Preparation 7-5: {'sal', 'hojas de col', 'aceite de oliva'}
# Preparation 7-6: {'trufa negra'}
# Preparation 7-7: {'trufa negra', 'sal', 'nata líquida', 'yema de huevo', 'aceite de oliva'}
# Preparation 7-8: {'sal', 'cebollino fresco', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-257: {'trufa negra', 'nata', 'mayonesa'}
# Preparation Elaboracion19871997-395: {'huevo entero'}
# Preparation Elaboracion19871997-467: {'trufa negra', 'hojas de col', 'aceite de oliva'}
# Preparation Elaboracion19871997-544: {'trufa negra', 'patata', 'salmón'}
#
# ********************************************************************************
#
# Recipe #8
# ============
#
# Preparations dat
# ----------------
# Preparation 8-1: {'judías verdes', 'sal'}
# Preparation 8-2: {'avellanas'}
# Preparation 8-3: {'trufa negra'}
# Preparation 8-4: {'jamón ibérico'}
# Preparation 8-5: {'bogavante'}
# Preparation 8-6: {'mollejas de ternera'}
# Preparation 8-7: {'trufa negra', 'pimienta negra', 'jugo de trufa negra', 'sal', 'orégano fresco', 'vinagre de jerez', 'avellanas'}
# Preparation 8-8: {'sal', 'pimienta negra', 'jamón', 'trufa', 'judías cocidas', 'avellanas'}
# Preparation 8-9: {'perifollo', 'sal', 'ensaladas variadas', 'cebollino fresco', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-225: {'trufa negra', 'vinagre de jerez', 'jugo de trufa negra', 'orégano', 'avellana'}
# Preparation Elaboracion19871997-466: {'trufa negra', 'judías verdes', 'mollejas de ternera', 'bogavante', 'avellana', 'jamón'}
#
# ********************************************************************************
#
# Recipe #9
# ============
#
# Preparations dat
# ----------------
# Preparation 9-1: {'salmonetes'}
# Preparation 9-2: {'patatas'}
# Preparation 9-3: {'trufas de verano', 'nata líquida', 'aceite de oliva'}
# Preparation 9-4: {'perifollo', 'sal', 'aceite de oliva'}
# Preparation 9-5: {'perifollo', 'sal', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-185: {'perifollo', 'sal', 'aceite de oliva'}
# Preparation Elaboracion19871997-418: {'nata', 'trufa de verano', 'aceite de oliva'}
#
# ********************************************************************************
#
# Recipe #10
# ============
#
# Preparations dat
# ----------------
# Preparation 10-1: {'pimiento', 'aceite de oliva'}
# Preparation 10-10: {'aceite de oliva', 'perifollo', 'pimienta negra', 'sal', 'piñones tostados', 'orégano fresco', 'vinagre balsámico'}
# Preparation 10-2: {'vinagre de jerez', 'pimienta negra', 'sal', 'pimiento rojo asado', 'aceite de oliva'}
# Preparation 10-3: {'chalotas'}
# Preparation 10-4: {'pimiento rojo'}
# Preparation 10-5: {'calabacín'}
# Preparation 10-6: {'cebollino fresco'}
# Preparation 10-7: {'tomates'}
# Preparation 10-8: {'aceite de oliva', 'pimienta negra', 'sal', 'verduras', 'salmonetes'}
# Preparation 10-9: {'anchoa en aceite', 'chalotas'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-301: {'vinagre de jerez', 'sal', 'pimiento rojo', 'aceite de oliva', 'pimienta negra'}
# Preparation Elaboracion19871997-420: {'pimiento rojo', 'pimiento rojo asado'}
# Preparation Elaboracion19871997-469: {'piñones', 'vinagre de Módena', 'chalota', 'anchoa'}
#
# ********************************************************************************
#
# Recipe #11
# ============
#
# Preparations dat
# ----------------
# Preparation 11-1: {'doradas'}
# Preparation 11-2: {'dorada', 'cebolla', 'ajo', 'aceite de oliva', 'tomate', 'zanahoria'}
# Preparation 11-3: {'patatas'}
# Preparation 11-4: {'ajo', 'sal', 'aceite de oliva'}
# Preparation 11-5: {'alioli', 'agua de mar', 'perejil', 'caldo de dorada', 'pimentón dulce', 'tomates maduros', 'ajo', 'sal', 'aceite de oliva', 'patata'}
# Preparation 11-6: {'perifollo'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-268: {'alioli', 'agua de mar', 'pimentón', 'ajo', 'perejil', 'caldo de dorada', 'tomate'}
# Preparation Elaboracion19871997-269: {'ajo', 'aceite'}
# Preparation Elaboracion19871997-322: {'dorada'}
#
# ********************************************************************************
#
# Recipe #12
# ============
#
# Preparations dat
# ----------------
# Preparation 12-1: {'escórporas'}
# Preparation 12-2: {'calamar'}
# Preparation 12-3: {'sal', 'tomate maduro', 'ajos', 'aceite de oliva', 'vinagre de jerez', 'avellanas tostadas', 'almendras'}
# Preparation 12-4: {'agua de mar', 'sal', 'romesco', 'mantequilla'}
# Preparation 12-5: {'perifollo', 'sal', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-270: {'agua de mar', 'mantequilla', 'romesco'}
# Preparation Elaboracion19871997-271: {'ajo', 'vinagre', 'nyora', 'avellana', 'almendra', 'tomate', 'aceite'}
#
# ********************************************************************************
#
# Recipe #13
# ============
#
# Preparations dat
# ----------------
# Preparation 13-1: set()
# Preparation 13-2: {'sal', 'habitas'}
# Preparation 13-3: {'jamón ibérico'}
# Preparation 13-4: {'cigalas', 'aceite de girasol'}
# Preparation 13-5: {'mostaza a la antigua', 'esencia de cigalas'}
# Preparation 13-6: {'perifollo', 'sal', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-273: {'mostaza a la antigua', 'esencia de cigala'}
#
# ********************************************************************************
#
# Recipe #14
# ============
#
# Preparations dat
# ----------------
# Preparation 14-1: set()
# Preparation 14-2: {'ceps', 'sal', 'filetes', 'aceite de oliva'}
# Preparation 14-3: {'perejil'}
# Preparation 14-4: {'puré de perejil', 'aceite de oliva'}
# Preparation 14-5: {'cigalas', 'aceite de girasol'}
# Preparation 14-6: {'cebollino', 'esencia de cigalas', 'aceite de oliva'}
# Preparation 14-7: {'hoja de laurel', 'ajo', 'ceps', 'aceite de girasol'}
# Preparation 14-8: {'trufa negra', 'perifollo', 'perejil', 'piñones tostados', 'pimienta negra', 'aceite de ceps', 'jugo de trufa negra', 'cebollino', 'sal', 'vinagre de jerez'}
# Preparation 14-9: {'perifollo'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-272: {'sal', 'perejil', 'aceite'}
# Preparation Elaboracion19871997-274: {'trufa negra', 'perifollo', 'perejil', 'pimienta negra', 'piñones', 'aceite de ceps', 'jugo de trufa negra', 'cebollino', 'vinagre de jerez'}
# Preparation Elaboracion19871997-275: {'cebollino', 'esencia de cigala', 'aceite de oliva'}
# Preparation Elaboracion19871997-419: {'perejil'}
# Preparation Elaboracion19871997-588: {'cep'}
#
# ********************************************************************************
#
# Recipe #15
# ============
#
# Preparations dat
# ----------------
# Preparation 15-1: {'blanqueta de ternera', 'puerro', 'cebolla', 'tomate maduro', 'agua', 'rodilla de ternera', 'aceite de oliva', 'zanahoria', 'vino tinto', 'azúcar'}
# Preparation 15-2: {'trufa negra', 'pimienta negra', 'oporto', 'fondo de carne', 'jugo de trufa negra', 'chalota', 'mantequilla', 'sal'}
# Preparation 15-3: {'pularda'}
# Preparation 15-4: {'foie-gras de pato'}
# Preparation 15-5: {'ceps frescos'}
# Preparation 15-6: {'láminas de ceps frescos', 'pularda', 'foie-gras de pato'}
# Preparation 15-7: {'romero', 'sal'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-277: {'trufa negra', 'oporto', 'mantequilla', 'chalota', 'fondo de carne'}
# Preparation Elaboracion19871997-543: {'láminas de ceps', 'pularda', 'foie-gras de pato'}
#
# ********************************************************************************
#
# Recipe #16
# ============
#
# Preparations dat
# ----------------
# Preparation 16-1: {'anchoa en salazón', 'zumo de limón', 'albahaca fresca', 'aceite de oliva'}
# Preparation 16-2: {'brotes de ensalada variada'}
# Preparation 16-3: {'atún'}
# Preparation 16-4: {'anchoa en aceite'}
# Preparation 16-5: {'baguette'}
# Preparation 16-6: {'piñones tostados', 'cebollino fresco', 'albahaca fresca'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-276: {'albahaca', 'limón', 'anchoa', 'aceite de oliva'}
# Preparation Elaboracion19871997-324: {'atún'}
# Preparation Elaboracion19871997-468: {'pan', 'limón', 'brotes de ensalada variada', 'aceite de oliva', 'piñones', 'albahaca', 'anchoa'}
# Preparation Elaboracion19871997-502: {'pan'}
#
# ********************************************************************************
#
# Recipe #17
# ============
#
# Preparations dat
# ----------------
# Preparation 17-1: {'erizos de mar'}
# Preparation 17-2: {'perejil fresco', 'perifollo', 'sal', 'cebollino fresco'}
# Preparation 17-3: {'agua de erizos', 'puré de hierbas', 'mantequilla', 'sal', 'pimienta negra', 'nata montada', 'jugo de trufa negra'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-158: {'erizo', 'salsa de erizo'}
# Preparation Elaboracion19871997-178: {'agua de erizos', 'puré de hierbas', 'mantequilla', 'pimienta negra', 'nata', 'jugo de trufa negra'}
# Preparation Elaboracion19871997-422: {'hierbas aromáticas', 'perifollo', 'perejil', 'agua', 'cebollino'}
#
# ********************************************************************************
#
# Recipe #18
# ============
#
# Preparations dat
# ----------------
# Preparation 18-1: {'ostras'}
# Preparation 18-2: {'habitas'}
# Preparation 18-3: {'zumo de limón', 'agua de ostras', 'aceite de oliva'}
# Preparation 18-4: {'ostras', 'agua de ostras', 'aceite de oliva'}
# Preparation 18-5: {'perifollo', 'caviar osietra'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-179: {'zumo de limón', 'agua de ostras', 'aceite de oliva'}
# Preparation Elaboracion19871997-351: {'ostra'}
#
# ********************************************************************************
#
# Recipe #19
# ============
#
# Preparations dat
# ----------------
# Preparation 19-1: {'almejas'}
# Preparation 19-2: {'trufa negra', 'sal', 'aceite de girasol'}
# Preparation 19-3: {'ajo', 'sal', 'ceps frescos', 'hoja de laurel', 'aceite de girasol'}
# Preparation 19-4: {'ceps'}
# Preparation 19-5: {'puerros'}
# Preparation 19-6: {'chalotas'}
# Preparation 19-7: {'mantequilla', 'sal', 'aceite de oliva', 'agua de almejas', 'cava', 'chalota'}
# Preparation 19-8: {'perifollo', 'sal', 'cebollino fresco', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-180: {'mantequilla', 'sal', 'aceite de oliva', 'agua de almejas', 'cava', 'chalota'}
# Preparation Elaboracion19871997-353: {'cep'}
#
# ********************************************************************************
#
# Recipe #20
# ============
#
# Preparations dat
# ----------------
# Preparation 20-1: {'ceps frescos'}
# Preparation 20-2: {'cebollas tiernas'}
# Preparation 20-3: {'agua de mar', 'agua'}
# Preparation 20-4: {'hoja de laurel', 'ajo', 'ceps', 'aceite de girasol'}
# Preparation 20-5: {'vinagre de jerez', 'sal', 'aceite de ceps', 'piñones tostados', 'cebollino fresco'}
# Preparation 20-6: {'sal', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-181: {'piñones', 'vinagre de jerez', 'cebollino', 'ceps', 'aceite'}
#
# ********************************************************************************
#
# Recipe #21
# ============
#
# Preparations dat
# ----------------
# Preparation 21-1: {'langostas'}
# Preparation 21-2: {'langosta', 'nata', 'clara de huevo'}
# Preparation 21-3: {'trufa negra'}
# Preparation 21-4: {'hojas de col'}
# Preparation 21-5: {'trufa negra', 'sal', 'arroz', 'cebollino fresco', 'aceite de oliva'}
# Preparation 21-6: {'aceite de oliva', 'zumo de limón', 'sal', 'yema de huevo', 'pimienta negra'}
# Preparation 21-7: {'nata semimontada', 'limón', 'cebollino fresco', 'chalota'}
# Preparation 21-8: {'perejil fresco', 'pan rallado', 'sal', 'huevo', 'langosta'}
# Preparation 21-9: {'aceite de oliva', 'perifollo', 'sal', 'aceite de girasol'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-174: {'mayonesa de limón', 'nata semimontada', 'cebollino'}
# Preparation Elaboracion19871997-397: {'yema de huevo'}
# Preparation Elaboracion19871997-471: {'trufa negra', 'cebollino', 'arroz', 'aceite de oliva'}
# Preparation Elaboracion19871997-568: set()
# Preparation Elaboracion19871997-594: set()
#
# ********************************************************************************
#
# Recipe #22
# ============
#
# Preparations dat
# ----------------
# Preparation 22-1: {'cigalas'}
# Preparation 22-2: {'patata', 'aceite de oliva'}
# Preparation 22-3: {'hoja de laurel', 'ajo', 'ceps', 'aceite de girasol'}
# Preparation 22-4: {'vinagre de jerez', 'sal', 'aceite de ceps', 'piñones tostados', 'cebollino fresco'}
# Preparation 22-5: {'calamares'}
# Preparation 22-6: {'sal', 'tomate maduro', 'aceite de oliva'}
# Preparation 22-7: {'vinagre de jerez', 'sal', 'aceite de girasol', 'yema de huevo', 'pimienta negra'}
# Preparation 22-8: {'tomate confitado', 'estragón fresco', 'mayonesa'}
# Preparation 22-9: {'perifollo', 'sal', 'cebollino fresco', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-175: {'estragón', 'tomate', 'mayonesa'}
# Preparation Elaboracion19871997-176: {'piñones', 'vinagre de jerez', 'aceite de ceps', 'cebollino fresco'}
# Preparation Elaboracion19871997-352: {'tomate'}
# Preparation Elaboracion19871997-396: {'yema de huevo'}
#
# ********************************************************************************
#
# Recipe #23
# ============
#
# Preparations dat
# ----------------
# Preparation 23-1: set()
# Preparation 23-2: {'espárragos'}
# Preparation 23-3: {'ajo', 'sal', 'rebozuelos', 'hoja de laurel', 'aceite de girasol'}
# Preparation 23-4: {'almendras', 'perejil fresco', 'ajo', 'sal', 'tomate maduro', 'aceite de oliva', 'vinagre de jerez', 'avellanas tostadas'}
# Preparation 23-5: {'aceite de confitar los rebozuelos', 'sal', 'vinagre de jerez', 'cebollino fresco'}
# Preparation 23-6: {'perifollo', 'sal', 'cebollino fresco', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-177: {'perejil', 'vinagre', 'nyora', 'avellana', 'tomate', 'aceite', 'almendra', 'ajo'}
# Preparation Elaboracion19871997-182: {'vinagre de jerez', 'aceite de rebozuelos', 'cebollino fresco'}
# Preparation Elaboracion19871997-355: {'rebozuelo'}
#
# ********************************************************************************
#
# Recipe #24
# ============
#
# Preparations dat
# ----------------
# Preparation 24-1: {'cigalas'}
# Preparation 24-2: set()
# Preparation 24-3: {'rebozuelos'}
# Preparation 24-4: {'trufa negra'}
# Preparation 24-5: {'patatas', 'sal', 'aceite de oliva'}
# Preparation 24-6: {'calabacines'}
# Preparation 24-7: {'trufa negra', 'aceite de girasol'}
# Preparation 24-8: {'perifollo', 'mantequilla', 'sal', 'aceite de oliva', 'cebollino fresco', 'jugo de trufa negra'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-183: {'cebollino', 'mantequilla', 'aceite de trufa negra', 'jugo de trufa negra'}
#
# ********************************************************************************
#
# Recipe #25
# ============
#
# Preparations dat
# ----------------
# Preparation 25-1: {'salmonetes'}
# Preparation 25-2: {'morralets'}
# Preparation 25-3: {'apio', 'puerro', 'hoja de laurel', 'orejas de cerdo', 'tomillo', 'zanahoria'}
# Preparation 25-4: {'ajo', 'sal', 'rebozuelos', 'hoja de laurel', 'aceite de girasol'}
# Preparation 25-5: {'anchoas en salazón', 'vinagre de jerez', 'aceite de confitar los rebozuelos', 'cebollino fresco'}
# Preparation 25-6: {'aceite de confitar los rebozuelos', 'sal', 'pimienta negra', 'rebozuelos laminados', 'col', 'oreja de cerdo'}
# Preparation 25-7: {'perifollo', 'sal', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-241: {'cebollino', 'aceite de rebozuelos', 'vinagre', 'anchoa'}
# Preparation Elaboracion19871997-354: {'rebozuelo'}
# Preparation Elaboracion19871997-470: {'morralets', 'ravioli de col', 'salmonete', 'vinagreta de anchoa', 'oreja de cerdo'}
# Preparation Elaboracion19871997-587: {'col'}
# Preparation Elaboracion19871997-599: {'juliana', 'pimienta negra', 'aceite de confitar los rebozuelos', 'oreja de cerdo', 'hojas de gelatina', 'rebozuelo laminado'}
#
# ********************************************************************************
#
# Recipe #26
# ============
#
# Preparations dat
# ----------------
# Preparation 26-1: {'escórporas'}
# Preparation 26-10: {'perifollo', 'sal', 'cebollino fresco', 'aceite de oliva'}
# Preparation 26-2: {'macarrones', 'sal'}
# Preparation 26-3: set()
# Preparation 26-4: {'aceite de oliva', 'ajo', 'sal', 'pimienta negra', 'azúcar', 'tomates'}
# Preparation 26-5: {'ajo', 'sal', 'perrechicos', 'hoja de laurel', 'rebozuelos', 'senderuelas', 'aceite de girasol'}
# Preparation 26-6: {'sepia'}
# Preparation 26-7: {'cebollas', 'tinta de sepia', 'sal', 'aceite de oliva'}
# Preparation 26-8: {'cebolla', 'sal', 'aceite de oliva'}
# Preparation 26-9: {'jugo de cebolla', 'pimienta verde', 'pimienta negra', 'pimienta blanca', 'chalota', 'brandy', 'mantequilla', 'sal', 'aceite de oliva', 'pimienta gris', 'pimienta rosa'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-240: {'jugo de cebolla', 'pimienta verde', 'pimienta negra', 'pimienta rosa', 'chalota', 'brandy', 'mantequilla', 'aceite de oliva', 'pimienta gris', 'pimienta blanca'}
# Preparation Elaboracion19871997-356: {'cebolla', 'tinta de sepia'}
# Preparation Elaboracion19871997-357: {'rebozuelo', 'senderuela', 'perrechico'}
# Preparation Elaboracion19871997-536: {'pasta de trigo duro'}
#
# ********************************************************************************
#
# Recipe #27
# ============
#
# Preparations dat
# ----------------
# Preparation 27-1: {'bogavantes'}
# Preparation 27-2: {'morillas'}
# Preparation 27-3: {'sal', 'habitas'}
# Preparation 27-4: {'perejil fresco', 'perifollo', 'sal', 'cebollino fresco'}
# Preparation 27-5: {'mollejas de ternera'}
# Preparation 27-6: {'ajo', 'bacalao desalado', 'aceite de oliva'}
# Preparation 27-7: {'perejil fresco', 'agua de mar', 'mantequilla', 'sal', 'aceite de oliva', 'jugo de trufa negra'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-239: {'agua de mar', 'puré de hierbas', 'mantequilla', 'jugo de trufa negra'}
# Preparation Elaboracion19871997-359: {'bacalao salado'}
# Preparation Elaboracion19871997-421: {'hierbas aromáticas', 'perifollo', 'perejil', 'agua', 'cebollino'}
#
# ********************************************************************************
#
# Recipe #28
# ============
#
# Preparations dat
# ----------------
# Preparation 28-1: {'gambas'}
# Preparation 28-2: {'gamba', 'aceite de oliva'}
# Preparation 28-3: {'gamba'}
# Preparation 28-4: {'patatas'}
# Preparation 28-5: {'ajo', 'sal', 'aceite de oliva'}
# Preparation 28-6: {'alioli', 'agua de mar', 'perejil', 'caldo de gambas', 'pimentón dulce', 'nata líquida', 'ajo', 'mantequilla', 'tomate maduro', 'sal', 'aceite de oliva', 'esencia de gambas', 'patatas'}
# Preparation 28-7: {'perejil fresco', 'sal', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-238: {'ajo', 'aceite de oliva'}
# Preparation Elaboracion19871997-245: {'pimentón', 'ajo', 'perejil', 'esencia de gamba', 'caldo de gamba', 'tomate', 'aceite'}
#
# ********************************************************************************
#
# Recipe #29
# ============
#
# Preparations dat
# ----------------
# Preparation 29-1: {'alubias', 'sal'}
# Preparation 29-2: {'cebollitas'}
# Preparation 29-3: {'senderuelas'}
# Preparation 29-4: {'apio', 'puerro', 'hoja de laurel', 'tomillo', 'oreja de cerdo', 'zanahoria'}
# Preparation 29-5: {'apio', 'cerdo', 'puerro', 'hoja de laurel', 'tomillo', 'zanahoria'}
# Preparation 29-6: {'blanqueta de ternera', 'puerro', 'cebolla', 'tomate maduro', 'agua', 'rodilla de ternera', 'aceite de oliva', 'zanahoria', 'vino tinto', 'azúcar'}
# Preparation 29-7: {'ajo', 'bacalao', 'aceite de oliva'}
# Preparation 29-8: {'aceite de oliva', 'perifollo', 'mantequilla', 'perejil', 'sal', 'pimienta negra', 'cebollino fresco'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-244: {'mantequilla', 'perejil', 'jugo de carne', 'pimienta negra'}
# Preparation Elaboracion19871997-358: {'bacalao salado'}
# Preparation Elaboracion19871997-571: set()
#
# ********************************************************************************
#
# Recipe #30
# ============
#
# Preparations dat
# ----------------
# Preparation 30-1: {'bogavantes'}
# Preparation 30-2: {'bogavantes', 'mantequilla', 'perejil', 'agua', 'jugo de trufa negra'}
# Preparation 30-3: {'patatas', 'hojas de repollo'}
# Preparation 30-4: {'mucosas'}
# Preparation 30-5: {'apio', 'puerro', 'hoja de laurel', 'tomillo', 'oreja de cerdo', 'zanahoria'}
# Preparation 30-6: {'trufa negra'}
# Preparation 30-7: {'tocino', 'sal', 'tomillo fresco', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-243: {'agua de cocción del bogavante', 'mantequilla', 'perejil', 'jugo de trufa negra'}
#
# ********************************************************************************
#
# Recipe #31
# ============
#
# Preparations dat
# ----------------
# Preparation 31-1: {'morralets'}
# Preparation 31-2: {'ajo', 'mantequilla'}
# Preparation 31-3: {'pimiento rojo'}
# Preparation 31-4: {'berenjena'}
# Preparation 31-5: {'cebolla'}
# Preparation 31-6: {'lentejas cocidas'}
# Preparation 31-7: {'almendra en polvo', 'sal', 'perejil', 'merluza', 'aceite de oliva'}
# Preparation 31-8: {'agua de mar', 'perifollo', 'ajo', 'sal', 'aceite de oliva', 'cebollino fresco'}
#
# Preparations nlg
# ----------------
#
# ********************************************************************************
#
# Recipe #32
# ============
#
# Preparations dat
# ----------------
# Preparation 32-1: {'langostas'}
# Preparation 32-2: {'blanqueta de ternera', 'puerro', 'cebolla', 'tomate maduro', 'agua', 'rodilla de ternera', 'aceite de oliva', 'zanahoria', 'vino tinto', 'azúcar'}
# Preparation 32-3: {'bacon'}
# Preparation 32-4: {'langosta', 'láminas de bacon'}
# Preparation 32-5: {'habitas'}
# Preparation 32-6: {'fondo de carne', 'mantequilla', 'perejil', 'coral de langosta', 'sal'}
# Preparation 32-7: {'sal', 'flores de romero', 'cebollino fresco', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-237: {'fondo de carne', 'mantequilla', 'perejil', 'coral de langosta'}
# Preparation Elaboracion19871997-242: {'fondo de atún'}
#
# ********************************************************************************
#
# Recipe #33
# ============
#
# Preparations dat
# ----------------
# Preparation 33-1: {'blanqueta de ternera', 'puerro', 'cebolla', 'tomate maduro', 'agua', 'rodilla de ternera', 'aceite de oliva', 'zanahoria', 'vino tinto', 'azúcar'}
# Preparation 33-2: {'yemas de huevo', 'sal', 'perejil', 'pato'}
# Preparation 33-3: {'trufa negra', 'pimienta negra', 'oporto', 'fondo de carne', 'chalotas', 'jugo de trufa negra', 'mantequilla', 'sal'}
# Preparation 33-4: {'sal', 'pimienta blanca', 'foie-gras de pato'}
# Preparation 33-5: {'endibia'}
# Preparation 33-6: {'romero', 'sal', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-236: {'trufa negra', 'chalota', 'jugo de trufa negra', 'mantequilla', 'pimienta negra', 'oporto', 'fondo de carne'}
# Preparation Elaboracion19871997-546: {'foie-gras de pato'}
#
# ********************************************************************************
#
# Recipe #34
# ============
#
# Preparations dat
# ----------------
# Preparation 34-1: set()
# Preparation 34-2: {'sal', 'habitas'}
# Preparation 34-3: {'levadura', 'sal', 'harina de trigo', 'agua', 'azúcar'}
# Preparation 34-4: {'cebolla tierna'}
# Preparation 34-5: {'apio', 'puerro', 'romero', 'tomillo', 'cebollas', 'aceite de oliva', 'zanahorias', 'laurel', 'vino tinto'}
# Preparation 34-6: {'perifollo', 'flores de romero', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-297: {'apio', 'puerro', 'romero', 'tomillo', 'cebolla', 'aceite de oliva', 'laurel', 'vino tinto', 'zanahoria'}
# Preparation Elaboracion19871997-364: {'pato'}
# Preparation Elaboracion19871997-570: set()
#
# ********************************************************************************
#
# Recipe #35
# ============
#
# Preparations dat
# ----------------
# Preparation 35-1: {'blanqueta de ternera', 'puerro', 'cebolla', 'tomate maduro', 'agua', 'rodilla de ternera', 'aceite de oliva', 'zanahoria', 'vino tinto', 'azúcar'}
# Preparation 35-2: {'pies de cerdo', 'apio', 'puerro', 'hoja de laurel', 'tomillo', 'zanahoria'}
# Preparation 35-3: {'caracoles', 'cebolla', 'apio', 'puerro', 'hoja de laurel', 'tomillo', 'zanahoria'}
# Preparation 35-4: {'ceps', 'agua', 'rebozuelos', 'senderuelas'}
# Preparation 35-5: {'conejo'}
# Preparation 35-6: {'fondo de carne', 'oporto', 'mantequilla', 'chalotas'}
# Preparation 35-7: {'perifollo', 'perejil', 'pimienta negra', 'caldo de setas', 'yemas de huevo', 'nata líquida', 'cebollino', 'sal'}
# Preparation 35-8: {'nata'}
# Preparation 35-9: {'pimienta negra', 'mantequilla', 'sal', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-295: {'fondo de carne', 'oporto', 'mantequilla', 'chalota'}
# Preparation Elaboracion19871997-298: {'nata', 'perejil', 'yema de huevo', 'pimienta negra'}
# Preparation Elaboracion19871997-399: {'yema de huevo'}
#
# ********************************************************************************
#
# Recipe #36
# ============
#
# Preparations dat
# ----------------
# Preparation 36-1: {'pichones'}
# Preparation 36-2: {'blanqueta de ternera', 'puerro', 'cebolla', 'tomate maduro', 'agua', 'rodilla de ternera', 'aceite de oliva', 'zanahoria', 'vino tinto', 'azúcar'}
# Preparation 36-3: {'aceite de oliva', 'pimienta negra', 'fondo de carne', 'muslos de pichón', 'ajo', 'sal', 'cebolla', 'zanahoria'}
# Preparation 36-4: {'trufa negra', 'pimienta negra', 'oporto', 'fondo de carne', 'chalotas', 'jugo de trufa negra', 'mantequilla', 'sal'}
# Preparation 36-5: {'trufa negra', 'nata líquida', 'mantequilla', 'perejil', 'sal', 'patatas'}
# Preparation 36-6: {'trufa negra'}
# Preparation 36-7: {'endibia'}
# Preparation 36-8: {'aceite de oliva', 'sal', 'salvia', 'pimienta negra'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-296: {'trufa negra', 'chalota', 'jugo de trufa negra', 'mantequilla', 'pimienta negra', 'oporto', 'fondo de carne'}
# Preparation Elaboracion19871997-383: {'muslos de pichón', 'cebolla', 'ajo', 'pichón', 'zanahoria', 'fondo de carne', 'aceite'}
# Preparation Elaboracion19871997-424: {'trufa negra', 'mantequilla', 'nata', 'patata'}
#
# ********************************************************************************
#
# Recipe #37
# ============
#
# Preparations dat
# ----------------
# Preparation 37-1: {'dados de piña', 'polvo de almendras', 'azúcar', 'piña', 'clara de huevo'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-110: {'puré de piña', 'polvo de almendras', 'azúcar', 'clara de huevo'}
#
# ********************************************************************************
#
# Recipe #38
# ============
#
# Preparations dat
# ----------------
# Preparation 38-1: {'azúcar lustre', 'harina', 'mantequilla', 'piel de naranja', 'huevo', 'polvo de almendras'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-112: {'harina', 'polvo de almendras', 'piel de naranja', 'mantequilla', 'Cointreau', 'azúcar'}
#
# ********************************************************************************
#
# Recipe #39
# ============
#
# Preparations dat
# ----------------
# Preparation 39-1: {'piñones', 'azúcar moreno', 'azúcar', 'clara de huevo'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-111: {'piñones', 'azúcar moreno', 'azúcar', 'clara de huevo'}
#
# ********************************************************************************
#
# Recipe #40
# ============
#
# Preparations dat
# ----------------
# Preparation 40-1: {'harina', 'mantequilla', 'huevo', 'agua', 'sal', 'leche', 'azúcar'}
# Preparation 40-2: {'glucosa', 'fondant'}
# Preparation 40-3: {'azúcar', 'nata montada'}
# Preparation 40-4: {'fresas'}
# Preparation 40-5: {'pistacho verde repelado'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-114: {'harina', 'mantequilla', 'huevo', 'agua', 'sal', 'leche', 'azúcar'}
# Preparation Elaboracion19871997-47: {'glucosa', 'caramelo neutro', 'fondant'}
# Preparation Elaboracion19871997-79: {'nata', 'azúcar'}
#
# ********************************************************************************
#
# Recipe #41
# ============
#
# Preparations dat
# ----------------
# Preparation 41-1: {'claras de huevo', 'pistacho verde repelado', 'harina', 'mantequilla', 'praliné de avellanas'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-113: {'harina', 'mantequilla', 'praliné', 'clara de huevo'}
# Preparation Elaboracion19871997-92: {'praliné de avellana'}
#
# ********************************************************************************
#
# Recipe #42
# ============
#
# Preparations dat
# ----------------
# Preparation 42-1: {'aceite de oliva', 'hojas de laurel', 'tomillo fresco', 'romero fresco', 'orégano fresco', 'albahaca fresca'}
# Preparation 42-2: {'hojaldre'}
# Preparation 42-3: {'calabacín', 'sal', 'tomate maduro', 'aceite de hierbas frescas', 'pimienta negra', 'hojaldre', 'azúcar'}
# Preparation 42-4: {'caracoles', 'cebolla', 'apio', 'puerro', 'hoja de laurel', 'tomillo', 'zanahoria'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-293: {'laurel fresco', 'aceite de oliva', 'tomillo fresco', 'romero fresco', 'orégano fresco', 'albahaca fresca'}
# Preparation Elaboracion19871997-504: {'hojaldre'}
# Preparation Elaboracion19871997-511: {'calabacín', 'caracoleses', 'hierbas aromáticas', 'tomate', 'hojaldre'}
#
# ********************************************************************************
#
# Recipe #43
# ============
#
# Preparations dat
# ----------------
# Preparation 43-1: {'bacalao desalado', 'aceite de oliva'}
# Preparation 43-2: {'bacalao desalado'}
# Preparation 43-3: {'sal', 'habitas'}
# Preparation 43-4: {'hojas de menta fresca'}
# Preparation 43-5: {'jamón ibérico'}
# Preparation 43-6: {'juliana de menta', 'aceite de oliva', 'jamón ibérico', 'habitas'}
# Preparation 43-7: {'tomates', 'sal', 'pimienta blanca', 'aceite de oliva'}
# Preparation 43-8: {'vinagre de jerez', 'sal', 'aceite de oliva', 'pimienta negra'}
# Preparation 43-9: {'cebollino fresco'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-294: {'aceite de oliva', 'sal', 'vinagre de jerez', 'pimienta negra'}
# Preparation Elaboracion19871997-363: {'bacalao salado'}
#
# ********************************************************************************
#
# Recipe #44
# ============
#
# Preparations dat
# ----------------
# Preparation 44-1: {'cigalas', 'agua', 'aceite de oliva'}
# Preparation 44-2: {'ceps frescos'}
# Preparation 44-3: {'ceps', 'aceite de girasol'}
# Preparation 44-4: {'caldo de cigalas', 'agua de mar', 'ajos', 'aceite de oliva', 'vinagre de jerez', 'almendras tiernas'}
# Preparation 44-5: {'espárragos verdes'}
# Preparation 44-6: {'cigala', 'aceite de girasol'}
# Preparation 44-7: {'pimienta negra', 'sal', 'melisa', 'almendras tiernas', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-445: {'agua de mar', 'vinagre', 'almendra tierna', 'ajo blanco', 'caldo de cigala', 'aceite'}
# Preparation Elaboracion19871997-473: {'espárragos verdes', 'melisa', 'almendra tierna'}
#
# ********************************************************************************
#
# Recipe #45
# ============
#
# Preparations dat
# ----------------
# Preparation 45-1: {'bogavantes', 'sal'}
# Preparation 45-10: {'tomates cherry', 'bogavante'}
# Preparation 45-11: {'cebollas tiernas', 'bogavante'}
# Preparation 45-12: {'perifollo', 'sal', 'cebollino fresco', 'aceite de oliva'}
# Preparation 45-2: {'bogavante'}
# Preparation 45-3: {'piñones tostados', 'bogavante', 'cebolla tierna', 'ajo', 'tomates rojos', 'vinagre de jerez', 'pepino', 'pimiento rojo'}
# Preparation 45-4: {'albahaca fresca', 'aceite de girasol'}
# Preparation 45-5: {'coral de bogavante', 'sal', 'aceite de albahaca', 'mayonesa', 'nata semimontada', 'vinagre de jerez', 'gazpacho'}
# Preparation 45-6: {'pimiento verde', 'tomate rojo', 'pepino', 'cebolla tierna', 'pimiento rojo', 'cebollino fresco'}
# Preparation 45-7: {'panecillo'}
# Preparation 45-8: {'pimientos'}
# Preparation 45-9: {'pepino'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-447: {'mayonesa', 'bogavante', 'piñones', 'albahaca', 'cebolla tierna', 'tomate', 'aceite', 'coral de bogavante', 'ajo', 'pepino', 'gazpacho', 'nata', 'pimiento rojo'}
# Preparation Elaboracion19871997-503: {'pan'}
#
# ********************************************************************************
#
# Recipe #46
# ============
#
# Preparations dat
# ----------------
# Preparation 46-1: {'pan', 'sal', 'tomate rojo', 'ajos', 'aceite de oliva'}
# Preparation 46-2: {'sal', 'baguette', 'aceite de girasol'}
# Preparation 46-3: {'aceite de oliva', 'sal', 'bonito'}
# Preparation 46-4: {'calabacín', 'sal'}
# Preparation 46-5: {'champiñones'}
# Preparation 46-6: {'ajo', 'agua'}
# Preparation 46-7: {'ajo', 'sal', 'yemas de huevo'}
# Preparation 46-8: {'perejil fresco', 'pimentón dulce', 'tomillo fresco'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-323: {'champiñones'}
# Preparation Elaboracion19871997-398: {'yema de huevo'}
# Preparation Elaboracion19871997-446: {'pan', 'ajo', 'sal', 'tomate', 'aceite'}
# Preparation Elaboracion19871997-506: {'pan'}
# Preparation Elaboracion19871997-573: set()
#
# ********************************************************************************
#
# Recipe #47
# ============
#
# Preparations dat
# ----------------
# Preparation 47-1: set()
# Preparation 47-10: {'ajo', 'sal', 'tomate maduro', 'aceite de oliva', 'vinagre de jerez', 'avellanas tostadas', 'almendras'}
# Preparation 47-11: {'baguette'}
# Preparation 47-12: {'perifollo', 'sal', 'aceite de oliva'}
# Preparation 47-2: {'salmonetes'}
# Preparation 47-3: set()
# Preparation 47-4: {'escórporas'}
# Preparation 47-5: {'lenguado'}
# Preparation 47-6: set()
# Preparation 47-7: set()
# Preparation 47-8: {'morralets'}
# Preparation 47-9: {'lluerna', 'espinas de salmonete', 'cigala', 'cebolla', 'ajo', 'tomate maduro', 'sal', 'aceite de oliva', 'escórpora'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-291: {'ajo', 'vinagre', 'nyora', 'avellana', 'almendra', 'tomate', 'aceite'}
# Preparation Elaboracion19871997-449: {'lluerna', 'escórpora', 'tomate', 'aceite', 'ajo', 'cebolla', 'rape', 'pescado', 'salmonete'}
# Preparation Elaboracion19871997-505: {'pan'}
#
# ********************************************************************************
#
# Recipe #48
# ============
#
# Preparations dat
# ----------------
# Preparation 48-1: {'alcachofas'}
# Preparation 48-2: {'nata líquida', 'mantequilla', 'alcachofa', 'sal', 'aceite de girasol'}
# Preparation 48-3: {'bueyes de mar', 'sal'}
# Preparation 48-4: {'trufa negra'}
# Preparation 48-5: {'perifollo'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-160: {'trufa negra', 'buey de mar', 'puré de alcachofa'}
# Preparation Elaboracion19871997-423: {'mantequilla', 'nata', 'alcachofa'}
#
# ********************************************************************************
#
# Recipe #49
# ============
#
# Preparations dat
# ----------------
# Preparation 49-1: {'blanqueta de ternera', 'puerro', 'cebolla', 'tomate maduro', 'agua', 'rodilla de ternera', 'aceite de oliva', 'zanahoria', 'vino tinto', 'azúcar'}
# Preparation 49-2: {'trufa negra', 'pimienta negra', 'oporto', 'fondo de carne', 'chalotas', 'jugo de trufa negra', 'mantequilla', 'sal'}
# Preparation 49-3: {'alcachofas', 'aceite de girasol'}
# Preparation 49-4: {'alcachofas', 'sal', 'agua', 'alcachofa'}
# Preparation 49-5: {'foie-gras de pato'}
# Preparation 49-6: {'espárragos verdes'}
# Preparation 49-7: {'trufa negra'}
# Preparation 49-8: {'harina de trigo', 'perifollo', 'sal', 'pistachos verdes'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-292: {'trufa negra', 'chalota', 'jugo de trufa negra', 'mantequilla', 'pimienta negra', 'oporto', 'fondo de carne'}
# Preparation Elaboracion19871997-448: {'sal', 'agua', 'alcachofa'}
#
# ********************************************************************************
#
# Recipe #50
# ============
#
# Preparations dat
# ----------------
# Preparation 50-1: {'agua', 'coquinas'}
# Preparation 50-2: {'patatas', 'sal'}
# Preparation 50-3: {'perifollo', 'mantequilla', 'sal', 'nata semimontada', 'cava', 'chalota'}
# Preparation 50-4: {'perifollo'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-289: {'perifollo', 'mantequilla', 'nata', 'cava', 'chalota'}
#
# ********************************************************************************
#
# Recipe #51
# ============
#
# Preparations dat
# ----------------
# Preparation 51-1: {'cola'}
# Preparation 51-2: {'patatas'}
# Preparation 51-3: {'sal', 'azafrán', 'patata', 'aceite de oliva'}
# Preparation 51-4: {'ajos tiernos', 'patatas'}
# Preparation 51-5: {'apio', 'puerro', 'zanahoria', 'hoja de laurel', 'tomillo', 'ternera'}
# Preparation 51-6: {'aceite de oliva', 'perifollo', 'sal', 'cebollino fresco', 'hinojo fresco'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-360: {'ajo tierno al azafrán'}
# Preparation Elaboracion19871997-361: {'patata al azafrán'}
#
# ********************************************************************************
#
# Recipe #52
# ============
#
# Preparations dat
# ----------------
# Preparation 52-1: {'ajo', 'hoja de laurel', 'ceps frescos', 'aceite de girasol'}
# Preparation 52-2: {'ceps'}
# Preparation 52-3: {'pimienta', 'panceta'}
# Preparation 52-4: {'sal', 'patata'}
# Preparation 52-5: {'trufa negra'}
# Preparation 52-6: {'trufa negra', 'perifollo', 'perejil', 'piñones tostados', 'pimienta negra', 'aceite de ceps', 'jugo de trufa negra', 'cebollino', 'sal', 'vinagre de jerez'}
# Preparation 52-7: {'conejo'}
# Preparation 52-8: {'cebolla tierna'}
# Preparation 52-9: {'hierba de los canónigos', 'perifollo', 'sal', 'pimienta rosa', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-290: {'trufa negra', 'perifollo', 'perejil', 'piñones', 'pimienta', 'aceite de ceps', 'jugo de trufa negra', 'cebollino', 'vinagre de jerez'}
# Preparation Elaboracion19871997-326: {'cep'}
# Preparation Elaboracion19871997-368: {'cep'}
# Preparation Elaboracion19871997-472: {'hierba de los canónigos', 'pimienta rosa', 'patata asada', 'juliana de panceta', 'láminas de trufa negra', 'cebolla tierna'}
#
# ********************************************************************************
#
# Recipe #53
# ============
#
# Preparations dat
# ----------------
# Preparation 53-1: {'espárragos verdes'}
# Preparation 53-2: {'trufa negra'}
# Preparation 53-3: {'patatas'}
# Preparation 53-4: {'ancas de rana'}
# Preparation 53-5: {'mantequilla', 'jugo de trufa negra'}
# Preparation 53-6: {'perifollo', 'sal', 'harina', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-205: {'mantequilla', 'jugo de trufa negra'}
# Preparation Elaboracion19871997-572: set()
# Preparation Elaboracion19871997-575: set()
#
# ********************************************************************************
#
# Recipe #54
# ============
#
# Preparations dat
# ----------------
# Preparation 54-1: {'cola'}
# Preparation 54-10: {'hierba de los canónigos', 'perifollo', 'escarola', 'apio'}
# Preparation 54-11: {'harina de trigo', 'perifollo', 'sal', 'aceite de oliva', 'aceite de girasol'}
# Preparation 54-2: {'pimienta'}
# Preparation 54-3: {'láminas de panceta', 'colas'}
# Preparation 54-4: {'espárragos verdes'}
# Preparation 54-5: {'ajo', 'sal', 'tomate maduro', 'aceite de oliva', 'vinagre de jerez', 'avellanas tostadas', 'almendras'}
# Preparation 54-6: {'cebollino fresco', 'sal', 'romesco', 'aceite de oliva'}
# Preparation 54-7: {'ancas de rana'}
# Preparation 54-8: {'manzana'}
# Preparation 54-9: {'alcachofa', 'aceite de girasol'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-204: {'cebollino', 'sal', 'romesco', 'aceite de oliva'}
# Preparation Elaboracion19871997-477: {'ancas de rana', 'perifollo', 'manzana', 'apio', 'hierba de los canónigos', 'escarola', 'alcachofa'}
# Preparation Elaboracion19871997-574: set()
#
# ********************************************************************************
#
# Recipe #55
# ============
#
# Preparations dat
# ----------------
# Preparation 55-1: {'pelayas'}
# Preparation 55-2: {'alcachofas', 'aceite de girasol'}
# Preparation 55-3: {'trufas'}
# Preparation 55-4: {'sal', 'oreja de cerdo', 'aceite de oliva'}
# Preparation 55-5: {'trufa negra', 'jugo de trufa negra'}
# Preparation 55-6: {'mostaza', 'perifollo', 'nata montada', 'cebollino fresco', 'puré de trufa negra'}
# Preparation 55-7: {'perifollo', 'sal', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-426: {'trufa negra', 'jugo de trufa negra'}
# Preparation Elaboracion19871997-476: {'trufa negra', 'pelaya', 'oreja de cerdo', 'alcachofa'}
# Preparation Elaboracion19871997-553: {'mostaza a la antigua', 'trufa negra', 'cebollino', 'perifollo', 'nata', 'puré de trufa negra'}
#
# ********************************************************************************
#
# Recipe #56
# ============
#
# Preparations dat
# ----------------
# Preparation 56-1: set()
# Preparation 56-2: {'merluza'}
# Preparation 56-3: {'trufa negra'}
# Preparation 56-4: {'espárragos verdes'}
# Preparation 56-5: {'perejil'}
# Preparation 56-6: {'perejil fresco', 'jugo de trufa negra', 'mantequilla', 'sal', 'puré de perejil'}
# Preparation 56-7: {'alcachofas', 'sal', 'aceite de girasol'}
# Preparation 56-8: {'perifollo', 'sal', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-207: {'perejil fresco', 'jugo de trufa negra', 'mantequilla', 'puré de perejil'}
# Preparation Elaboracion19871997-425: {'perejil', 'agua'}
# Preparation Elaboracion19871997-577: set()
#
# ********************************************************************************
#
# Recipe #57
# ============
#
# Preparations dat
# ----------------
# Preparation 57-1: set()
# Preparation 57-2: {'ostras'}
# Preparation 57-3: {'levadura', 'sal', 'harina de trigo', 'agua', 'azúcar'}
# Preparation 57-4: {'perejil fresco', 'agua'}
# Preparation 57-5: {'puré de perejil', 'cebollino fresco', 'mantequilla', 'caviar osietra', 'sal'}
# Preparation 57-6: {'aceite de oliva', 'sal', 'caviar osietra', 'cebollino fresco', 'aceite de girasol'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-206: {'puré de perejil', 'cebollino', 'mantequilla', 'caviar osietra'}
# Preparation Elaboracion19871997-428: {'perejil', 'agua'}
# Preparation Elaboracion19871997-576: set()
#
# ********************************************************************************
#
# Recipe #58
# ============
#
# Preparations dat
# ----------------
# Preparation 58-1: set()
# Preparation 58-2: {'rebozuelos'}
# Preparation 58-3: {'bogavante'}
# Preparation 58-4: {'perejil fresco', 'esencia de bogavante', 'ajo', 'zumo de limón', 'aceite de oliva'}
# Preparation 58-5: {'pimientos', 'sal', 'cebollino fresco', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-201: {'coral de bogavante', 'aceite de oliva', 'perejil fresco', 'ajo', 'zumo de limón'}
# Preparation Elaboracion19871997-579: set()
#
# ********************************************************************************
#
# Recipe #59
# ============
#
# Preparations dat
# ----------------
# Preparation 59-1: {'lubinas'}
# Preparation 59-2: {'cebollitas', 'tomates cherry', 'ajo', 'patatas'}
# Preparation 59-3: {'lubina', 'cebolla', 'ajo', 'aceite de oliva', 'tomate', 'zanahoria'}
# Preparation 59-4: {'perifollo', 'mantequilla', 'perejil', 'sal', 'aceite de oliva', 'cebollino fresco'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion19871997-200: {'lubina', 'cebollino', 'mantequilla', 'perejil'}
#
# ...
# Preparation Elaboracion2005-656: {'puré de fruta de la pasión'}
# Preparation Elaboracion2005-657: {'puré de albaricoque'}
# Preparation Elaboracion2005-658: {'piel de limón', 'zumo de limón', 'ácido cítrico', 'azúcar'}
# Preparation Elaboracion2005-659: {'limón'}
# Preparation Elaboracion2005-660: set()
# Preparation Elaboracion2005-661: set()
# Preparation Elaboracion2005-662: set()
# Preparation Elaboracion2005-663: {'azúcar invertido', 'puré de fruta de la pasión', 'estabilizante para helado', 'agua', 'fruta de la pasión', 'leche en polvo', 'chocolate con leche', 'azúcar'}
# Preparation Elaboracion2005-664: {'AGAR', 'agua', 'jarabe', 'hojas de gelatina', 'puré de albaricoque', 'albaricoque'}
# Preparation Elaboracion2005-665: {'gelatina fría de puré de albaricoque', 'baño de chocolate blanco'}
# Preparation Elaboracion2005-666: {'praliné de avellana', 'feuillantine'}
# Preparation Elaboracion2005-667: {'chocolate blanco'}
# Preparation Elaboracion2005-668: {'nata', 'chocolate blanco', 'yogur griego'}
# Preparation Elaboracion2005-669: {'nata', 'chocolate blanco', 'yogur griego'}
#
# ********************************************************************************
#
# Recipe #1198
# ============
#
# Preparations dat
# ----------------
# Preparation 1198-1: {'lecitina de soja', 'chocolate', 'agua', 'praliné de avellana'}
# Preparation 1198-10: {'nata líquida', 'praliné de avellana'}
# Preparation 1198-11: {'nibs de cacao'}
# Preparation 1198-2: {'aire de chocolate', 'praliné de avellana'}
# Preparation 1198-3: {'nata líquida', 'cacao en polvo', 'chocolate', 'agua', 'azúcar'}
# Preparation 1198-4: {'agua', 'azúcar'}
# Preparation 1198-5: {'jarabe 100 ?', 'pera', 'café exprés'}
# Preparation 1198-6: {'café'}
# Preparation 1198-7: {'glucosa', 'fruta de la pasión liofilizada', 'fondant'}
# Preparation 1198-8: {'sal', 'avellanas tostadas', 'aceite de oliva'}
# Preparation 1198-9: {'avellanas tostadas', 'fruta de la pasión'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-670: {'avellana frita', 'caramelo de fruta de la pasión'}
# Preparation Elaboracion2005-671: {'praliné de avellana', 'nata', 'avellana'}
# Preparation Elaboracion2005-672: {'chocolate', 'LECITE', 'agua', 'praliné de avellana'}
# Preparation Elaboracion2005-673: {'avellana'}
# Preparation Elaboracion2005-674: set()
# Preparation Elaboracion2005-675: set()
# Preparation Elaboracion2005-676: {'nata líquida', 'agua', 'cacao', 'chocolate', 'azúcar'}
# Preparation Elaboracion2005-677: {'chocolate', 'aire de chocolate y praliné de avellana'}
# Preparation Elaboracion2005-678: {'glucosa', 'fruta de la pasión liofilizada', 'Isomalt', 'fruta de la pasión', 'fondant'}
#
# ********************************************************************************
#
# Recipe #1199
# ============
#
# Preparations dat
# ----------------
# Preparation 1199-1: {'clara de huevo en polvo', 'agua', 'clara de huevo pasteurizada', 'azúcar', 'café soluble'}
# Preparation 1199-10: {'regaliz', 'chocolate templado', 'pasta'}
# Preparation 1199-11: {'crispy de frambuesa liofilizada', 'yogur griego'}
# Preparation 1199-2: {'clara de huevo en polvo', 'pasta de regaliz', 'agua', 'clara de huevo pasteurizada', 'azúcar'}
# Preparation 1199-3: {'azúcar invertido', 'leche', 'canela', 'dextrosa', 'yema de huevo', 'leche en polvo', 'estabilizante para helados', 'nata', 'azúcar'}
# Preparation 1199-4: {'agua', 'azúcar'}
# Preparation 1199-5: {'frambuesas', 'jarabe 60 ?', 'azúcar'}
# Preparation 1199-6: {'jugo de frambuesas', 'hoja de gelatina', 'agua'}
# Preparation 1199-7: {'pan de especias'}
# Preparation 1199-8: {'azúcar lustre', 'canela en polvo'}
# Preparation 1199-9: {'canela en polvo', 'kadaif'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-679: set()
# Preparation Elaboracion2005-680: set()
# Preparation Elaboracion2005-681: set()
# Preparation Elaboracion2005-682: set()
# Preparation Elaboracion2005-683: set()
# Preparation Elaboracion2005-684: {'azúcar lustre', 'canela en polvo'}
# Preparation Elaboracion2005-685: {'frambuesa'}
# Preparation Elaboracion2005-686: set()
# Preparation Elaboracion2005-687: {'azúcar invertido', 'canela caramelizada', 'leche', 'dextrosa', 'estabilizante para helado', 'yema de huevo', 'caramelo', 'leche en polvo', 'nata', 'azúcar'}
# Preparation Elaboracion2005-688: {'jugo de frambuesa', 'hojas de gelatina', 'frambuesa'}
#
# ********************************************************************************
#
# Recipe #1200
# ============
#
# Preparations dat
# ----------------
# Preparation 1200-1: {'piña'}
# Preparation 1200-2: {'anís estrellado', 'piña', 'hinojo fresco'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-689: {'hinojo fresco', 'anís', 'piña'}
#
# ********************************************************************************
#
# Recipe #1201
# ============
#
# Preparations dat
# ----------------
# Preparation 1201-1: {'alginato sódico', 'agua', 'concentrado de flor de saúco'}
# Preparation 1201-2: {'cerezas'}
# Preparation 1201-3: {'yogur natural', 'azúcar'}
# Preparation 1201-4: {'agua', 'concentrado de flor de saúco'}
# Preparation 1201-5: {'cerezas', 'azúcar', 'saúco'}
# Preparation 1201-6: {'flores de saúco'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-690: {'ALGIN', 'cereza', 'saúco', 'yogur'}
# Preparation Elaboracion2005-691: {'ALGIN', 'agua', 'concentrado de flor de saúco'}
# Preparation Elaboracion2005-692: {'yogur'}
#
# ********************************************************************************
#
# Recipe #1202
# ============
#
# Preparations dat
# ----------------
# Preparation 1202-1: {'agua', 'azúcar'}
# Preparation 1202-2: {'jarabe 100 ?', 'ron blanco', 'zumo de limón', 'limón', 'agua', 'agar-agar', 'hoja de gelatina'}
# Preparation 1202-3: {'zumo de limón', 'hoja de gelatina', 'limón', 'agua'}
# Preparation 1202-4: {'gelatina fría', 'daikiri', 'nube de limón'}
# Preparation 1202-5: {'jarabe 100 ?', 'café exprés', 'agua', 'hojas de gelatina'}
# Preparation 1202-6: {'caramelos', 'caramelo'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-693: {'piel de limón', 'zumo de limón', 'limón', 'agua', 'hojas de gelatina'}
# Preparation Elaboracion2005-694: {'café exprés', 'jarabe', 'café', 'AGAR', 'hojas de gelatina'}
# Preparation Elaboracion2005-695: {'ron blanco', 'zumo de limón', 'AGAR', 'agua', 'piel de limón', 'jarabe', 'daikiri', 'hojas de gelatina'}
# Preparation Elaboracion2005-696: {'daikiri', 'gelatina fría de daikiri'}
# Preparation Elaboracion2005-697: {'daikiri', 'nube de limón', 'compacto de daikiri'}
# Preparation Elaboracion2005-698: {'barrita helada de daikiri', 'caramelo japonés', 'café', 'daikiri', 'gelatina fría de café'}
# Preparation Elaboracion2005-699: {'ron blanco', 'zumo de limón', 'agua', 'piel de limón', 'jarabe', 'hojas de gelatina'}
#
# ********************************************************************************
#
# Recipe #1203
# ============
#
# Preparations dat
# ----------------
# Preparation 1203-1: set()
# Preparation 1203-10: {'café'}
# Preparation 1203-11: {'fécula de patata', 'café'}
# Preparation 1203-12: {'agua', 'azúcar'}
# Preparation 1203-13: {'nata líquida', 'pulpa de guanábana', 'jarabe 60 ?', 'agua', 'hojas de gelatina'}
# Preparation 1203-14: {'fruta de la pasión'}
# Preparation 1203-2: {'fécula de patata'}
# Preparation 1203-3: {'nata líquida', 'yogur natural', 'agua', 'hojas de gelatina', 'ácido cítrico', 'azúcar', 'yogur griego'}
# Preparation 1203-4: {'jarabe 100 ?', 'té matcha'}
# Preparation 1203-5: {'frambuesas', 'flores de romero'}
# Preparation 1203-6: {'fruta de la pasión'}
# Preparation 1203-7: {'fécula de patata', 'fruta de la pasión'}
# Preparation 1203-8: {'nata líquida', 'azúcar'}
# Preparation 1203-9: {'pasta de regaliz', 'albahaca', 'fruta de la pasión'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-700: {'pulpa de guanábana'}
# Preparation Elaboracion2005-701: {'pasta de regaliz'}
# Preparation Elaboracion2005-702: {'puré de fruta de la pasión'}
# Preparation Elaboracion2005-703: {'nata líquida', 'yogur griego', 'azúcar', 'ácido cítrico', 'hojas de gelatina', 'yogur'}
# Preparation Elaboracion2005-704: {'nata', 'azúcar'}
# Preparation Elaboracion2005-705: set()
# Preparation Elaboracion2005-706: set()
# Preparation Elaboracion2005-707: set()
# Preparation Elaboracion2005-708: set()
# Preparation Elaboracion2005-709: {'guanábana', 'jarabe', 'pulpa de guanábana', 'nata', 'hojas de gelatina'}
# Preparation Elaboracion2005-710: {'nata', 'yogur'}
# Preparation Elaboracion2005-711: {'nata'}
#
# ********************************************************************************
#
# Recipe #1204
# ============
#
# Preparations dat
# ----------------
# Preparation 1204-1: {'clara de huevo en polvo', 'agua', 'clara de huevo pasteurizada', 'azúcar', 'café soluble'}
# Preparation 1204-2: {'nata líquida', 'chocolate', 'agua', 'café soluble'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-712: set()
# Preparation Elaboracion2005-713: set()
#
# ********************************************************************************
#
# Recipe #1205
# ============
#
# Preparations dat
# ----------------
# Preparation 1205-1: {'miel de romero', 'agua'}
# Preparation 1205-2: {'miel de romero', 'clara de huevo pasteurizada'}
# Preparation 1205-3: {'miel de romero', 'azúcar lustre', 'limón'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-714: set()
# Preparation Elaboracion2005-715: {'miel'}
#
# ********************************************************************************
#
# Recipe #1206
# ============
#
# Preparations dat
# ----------------
# Preparation 1206-1: {'bicarbonato sódico', 'agua', 'huevos enteros', 'harina de trigo', 'azúcar', 'miel de romero'}
# Preparation 1206-2: {'castaña', 'azúcar lustre', 'praliné de avellana', 'vaina de vainilla'}
# Preparation 1206-3: {'azúcar lustre', 'aceite de oliva'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-716: set()
# Preparation Elaboracion2005-717: {'castaña'}
#
# ********************************************************************************
#
# Recipe #1207
# ============
#
# Preparations dat
# ----------------
# Preparation 1207-1: {'crispy de fruta de la pasión'}
# Preparation 1207-2: {'azúcar moreno', 'plata'}
# Preparation 1207-3: {'azúcar'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-718: set()
#
# ********************************************************************************
#
# Recipe #1208
# ============
#
# Preparations dat
# ----------------
# Preparation 1208-1: {'menta chocolatera', 'ácido ascórbico'}
# Preparation 1208-2: {'agua de menta', 'leche', 'agua', 'hojas de gelatina', 'azúcar'}
# Preparation 1208-3: {'manteca de cacao', 'chocolate', 'menta'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-719: {'menta chocolatera'}
# Preparation Elaboracion2005-720: {'menta chocolatera', 'jugo de menta chocolatera', 'leche', 'hojas de gelatina', 'azúcar'}
# Preparation Elaboracion2005-721: set()
# Preparation Elaboracion2005-722: {'leche'}
#
# ********************************************************************************
#
# Recipe #1209
# ============
#
# Preparations dat
# ----------------
# Preparation 1209-1: {'glucosa', 'fruta de la pasión liofilizada', 'caramelo de fruta de la pasión', 'fondant'}
# Preparation 1209-2: {'chocolate', 'praliné de avellana'}
# Preparation 1209-3: {'caramelo de fruta de la pasión'}
# Preparation 1209-4: {'fruta', 'praliné de avellana', 'chocolate negro', 'pasión'}
# Preparation 1209-5: {'caramelo de yogur', 'glucosa', 'fondant', 'yogur en polvo'}
# Preparation 1209-6: {'chocolate blanco'}
# Preparation 1209-7: {'caramelo yogur'}
# Preparation 1209-8: {'caramelo de yogur', 'nuez de macadamia', 'chocolate blanco'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-723: set()
# Preparation Elaboracion2005-724: set()
# Preparation Elaboracion2005-725: {'glucosa', 'Isomalt', 'yogur', 'fondant', 'yogur en polvo'}
# Preparation Elaboracion2005-726: {'glucosa', 'fruta de la pasión liofilizada', 'Isomalt', 'fruta de la pasión', 'fondant'}
#
# ********************************************************************************
#
# Recipe #1210
# ============
#
# Preparations dat
# ----------------
# Preparation 1210-1: {'concentrado de fresas'}
# Preparation 1210-2: {'agua', 'azúcar'}
# Preparation 1210-3: {'jarabe 100 ?', 'fresas', 'limón', 'concentrado de fresas'}
# Preparation 1210-4: {'fresa'}
# Preparation 1210-5: {'manteca de cacao', 'chocolate'}
# Preparation 1210-6: {'eucalipto', 'neutro'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-727: {'concentrado de fresa'}
# Preparation Elaboracion2005-728: {'Peta Zetas neutro encapsulado'}
# Preparation Elaboracion2005-729: {'fresa'}
# Preparation Elaboracion2005-730: set()
# Preparation Elaboracion2005-731: {'fresas', 'jarabe', 'fresa', 'limón', 'concentrado de fresa'}
#
# ********************************************************************************
#
# Recipe #1211
# ============
#
# Preparations dat
# ----------------
# Preparation 1211-1: {'agua', 'azúcar'}
# Preparation 1211-2: {'jarabe 100 ?', 'glucosa', 'estabilizante para sorbetes', 'frambuesas'}
# Preparation 1211-3: {'azúcar invertido', 'puré de fruta de la pasión', 'agua', 'leche en polvo', 'estabilizante para helados', 'chocolate con leche', 'azúcar'}
# Preparation 1211-4: {'manteca de cacao', 'chocolate'}
# Preparation 1211-5: {'manteca de cacao', 'líquido'}
# Preparation 1211-6: {'manteca de cacao', 'chocolate blanco'}
# Preparation 1211-7: {'líquido', 'chocolate blanco', 'cacao'}
# Preparation 1211-8: {'hielo pilé'}
# Preparation 1211-9: {'crispy de fruta de la pasión', 'crispy de frambuesa'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-732: {'glucosa', 'jarabe', 'estabilizante para sorbetes', 'frambuesa'}
# Preparation Elaboracion2005-733: {'manteca de cacao', 'chocolate blanco'}
# Preparation Elaboracion2005-734: {'manteca de cacao', 'chocolate'}
# Preparation Elaboracion2005-735: set()
# Preparation Elaboracion2005-736: set()
# Preparation Elaboracion2005-737: set()
# Preparation Elaboracion2005-738: {'azúcar invertido', 'puré de fruta de la pasión', 'estabilizante para helado', 'agua', 'fruta de la pasión', 'leche en polvo', 'chocolate con leche', 'azúcar'}
# Preparation Elaboracion2005-739: {'chocolate blanco'}
# Preparation Elaboracion2005-740: {'crispy de frambuesa', 'chocolate negro', 'chocolate', 'sorbete de frambuesa', 'frambuesa'}
# Preparation Elaboracion2005-741: {'crispy de fruta de la pasión', 'helado de chocolate con leche y fruta de la pasión', 'chocolate blanco', 'fruta de la pasión', 'chocolate con leche'}
#
# ********************************************************************************
#
# Recipe #1212
# ============
#
# Preparations dat
# ----------------
# Preparation 1212-1: {'frambuesa liofilizada en polvo', 'chocolate templado'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-742: set()
#
# ********************************************************************************
#
# Recipe #1213
# ============
#
# Preparations dat
# ----------------
# Preparation 1213-1: {'chocolate templado', 'frambuesa'}
# Preparation 1213-2: {'fruta de la pasión', 'chocolate blanco'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-743: set()
# Preparation Elaboracion2005-744: set()
#
# ********************************************************************************
#
# Recipe #1214
# ============
#
# Preparations dat
# ----------------
# Preparation 1214-1: {'frambuesas liofilizadas', 'chocolate templado'}
# Preparation 1214-2: {'dextrosa', 'ácido cítrico en polvo', 'yogur en polvo', 'yogur'}
# Preparation 1214-3: {'rosas', 'fresas liofilizadas', 'chocolate blanco', 'yogur'}
# Preparation 1214-4: {'albaricoques', 'albaricoque'}
# Preparation 1214-5: {'hojas de menta fresca'}
# Preparation 1214-6: {'menta', 'chocolate blanco', 'albaricoque'}
# Preparation 1214-7: {'melocotón', 'melocotones'}
# Preparation 1214-8: {'hierba luisa fresca'}
# Preparation 1214-9: {'hierba luisa', 'melocotón', 'chocolate con leche'}
#
# Preparations nlg
# ----------------
# Preparation Elaboracion2005-745: {'dextrosa', 'ácido cítrico', 'yogur en polvo'}
# Preparation Elaboracion2005-746: set()
# Preparation Elaboracion2005-747: set()
# Preparation Elaboracion2005-748: set()
# Preparation Elaboracion2005-749: set()
#
# ********************************************************************************

# %%
mappings = {
    '1214-2': 'Elaboracion2005-745'
}
